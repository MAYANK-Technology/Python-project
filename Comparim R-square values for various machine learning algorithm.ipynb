# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets

# load the Boston dataset
data = datasets.load_boston()
X, y = data.data, data.target

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

clf = LazyRegressor(predictions=True)

# fit the data using different algorithms
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-04766a85bec5> in <module>
# ----> 1 from lazypredict.Supervised import LazyRegressor
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn import datasets
#       4
#       5 # load the Boston dataset
#
# ModuleNotFoundError: No module named 'lazypredict'

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-5d4fc5db1206> in <module>
# ----> 1 from lazypredict.Supervised import LazyRegressor
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn import datasets
#
# ModuleNotFoundError: No module named 'lazypredict'

# %%
pip install lazypredict
# Out:
# Collecting lazypredictNote: you may need to restart the kernel to use updated packages.
#
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Collecting xgboost
#   Downloading xgboost-1.7.5-py3-none-win_amd64.whl (70.9 MB)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (4.50.2)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (0.17.0)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (1.1.3)
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (0.23.2)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from xgboost->lazypredict) (1.5.2)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from xgboost->lazypredict) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\programdata\anaconda3\lib\site-packages (from pandas->lazypredict) (2020.1)
# Requirement already satisfied: wheel in c:\programdata\anaconda3\lib\site-packages (from lightgbm->lazypredict) (0.35.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->lazypredict) (2.1.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Installing collected packages: xgboost, lightgbm, lazypredict
# Successfully installed lazypredict-0.2.12 lightgbm-3.3.5 xgboost-1.7.5

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets

# load the Boston dataset
data = datasets.load_boston()
X, y = data.data, data.target

# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

clf = LazyRegressor(predictions=True)

# fit the data using different algorithms
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 41/41 [00:04<00:00,  9.78it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.90       0.92  2.49        0.16
# XGBRegressor                                 0.89       0.91  2.60        0.19
# RandomForestRegressor                        0.88       0.89  2.81        0.43
# LGBMRegressor                                0.87       0.89  2.83        0.08
# ExtraTreesRegressor                          0.85       0.87  3.12        0.36
# BaggingRegressor                             0.84       0.86  3.15        0.08
# HistGradientBoostingRegressor                0.84       0.86  3.18        0.61
# DecisionTreeRegressor                        0.84       0.86  3.23        0.03
# AdaBoostRegressor                            0.81       0.84  3.45        0.17
# PoissonRegressor                             0.73       0.76  4.16        0.01
# ExtraTreeRegressor                           0.71       0.75  4.29        0.01
# KNeighborsRegressor                          0.68       0.72  4.54        0.03
# RANSACRegressor                              0.67       0.71  4.58        0.11
# TransformedTargetRegressor                   0.62       0.67  4.93        0.02
# LinearRegression                             0.62       0.67  4.93        0.03
# Lars                                         0.62       0.67  4.93        0.02
# LassoLarsCV                                  0.62       0.67  4.93        0.05
# Ridge                                        0.62       0.67  4.93        0.02
# LassoCV                                      0.62       0.67  4.93        0.09
# ElasticNetCV                                 0.62       0.67  4.94        0.10
# BayesianRidge                                0.62       0.67  4.94        0.14
# RidgeCV                                      0.62       0.67  4.95        0.03
# LarsCV                                       0.62       0.66  4.96        0.03
# SGDRegressor                                 0.61       0.66  4.99        0.00
# SVR                                          0.60       0.65  5.07        0.05
# GammaRegressor                               0.59       0.64  5.12        0.02
# NuSVR                                        0.58       0.63  5.17        0.04
# LassoLarsIC                                  0.58       0.63  5.19        0.01
# MLPRegressor                                 0.57       0.63  5.21        0.88
# Lasso                                        0.57       0.62  5.25        0.02
# HuberRegressor                               0.56       0.61  5.32        0.10
# ElasticNet                                   0.56       0.61  5.33        0.03
# TweedieRegressor                             0.56       0.61  5.33        0.02
# OrthogonalMatchingPursuitCV                  0.55       0.61  5.37        0.03
# LinearSVR                                    0.53       0.59  5.49        0.02
# OrthogonalMatchingPursuit                    0.48       0.54  5.79        0.01
# GaussianProcessRegressor                     0.23       0.33  7.00        0.04
# DummyRegressor                              -0.17      -0.02  8.66        0.03
# LassoLars                                   -0.17      -0.02  8.66        0.02
# PassiveAggressiveRegressor                  -0.33      -0.15  9.20        0.02
# KernelRidge                                 -7.68      -6.57 23.56        0.03

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd

# load the Boston dataset
data = pd.read_csv('thesis_final.csv')
X = data[['No_of_passengers', 'temperature']]
y = data['charge_used']


# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

clf = LazyRegressor(predictions=True)

# fit the data using different algorithms
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-53e727580d0f> in <module>
#       5
#       6 # load the Boston dataset
# ----> 7 data = pd.read_csv('thesis_final.csv')
#       8 X = data[['No_of_passengers', 'temperature']]
#       9 y = data['charge_used']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'thesis_final.csv'

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd

# load the Boston dataset
data = pd.read_csv('thesis_final.csv')
X = data[['No_of_passengers', 'temperature']]
y = data['charge_used']


# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

clf = LazyRegressor(predictions=True)

# fit the data using different algorithms
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-53e727580d0f> in <module>
#       5
#       6 # load the Boston dataset
# ----> 7 data = pd.read_csv('thesis_final.csv')
#       8 X = data[['No_of_passengers', 'temperature']]
#       9 y = data['charge_used']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'thesis_final.csv'

# %%
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
from sklearn import datasets
import pandas as pd

# load the Boston dataset
data = pd.read_csv('final_data.csv')
X = data[['No_of_passengers', 'temperature']]
y = data['charge_used']


# split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)

clf = LazyRegressor(predictions=True)

# fit the data using different algorithms
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 41/41 [00:06<00:00,  5.92it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# GradientBoostingRegressor                    0.86       0.86  0.71        0.11
# AdaBoostRegressor                            0.85       0.85  0.73        0.14
# HistGradientBoostingRegressor                0.85       0.85  0.74        0.68
# LGBMRegressor                                0.85       0.85  0.74        0.13
# XGBRegressor                                 0.83       0.83  0.77        0.14
# RandomForestRegressor                        0.83       0.83  0.77        0.43
# SVR                                          0.83       0.83  0.78        0.23
# KNeighborsRegressor                          0.83       0.83  0.78        0.03
# BaggingRegressor                             0.83       0.83  0.78        0.05
# ExtraTreeRegressor                           0.83       0.83  0.79        0.02
# NuSVR                                        0.82       0.82  0.80        0.20
# DecisionTreeRegressor                        0.82       0.82  0.80        0.02
# ExtraTreesRegressor                          0.82       0.82  0.80        0.32
# GaussianProcessRegressor                     0.75       0.75  0.94        0.57
# MLPRegressor                                 0.72       0.72  0.99        2.92
# LassoLarsIC                                  0.71       0.71  1.01        0.02
# LarsCV                                       0.71       0.71  1.01        0.02
# LassoLarsCV                                  0.71       0.71  1.01        0.02
# Lars                                         0.71       0.71  1.01        0.03
# TransformedTargetRegressor                   0.71       0.71  1.01        0.02
# LinearRegression                             0.71       0.71  1.01        0.02
# RidgeCV                                      0.71       0.71  1.01        0.02
# BayesianRidge                                0.71       0.71  1.01        0.09
# Ridge                                        0.71       0.71  1.01        0.02
# LassoCV                                      0.71       0.71  1.02        0.09
# ElasticNetCV                                 0.71       0.71  1.02        0.09
# SGDRegressor                                 0.71       0.71  1.02        0.02
# OrthogonalMatchingPursuitCV                  0.71       0.71  1.02        0.02
# OrthogonalMatchingPursuit                    0.71       0.71  1.02        0.01
# HuberRegressor                               0.70       0.71  1.03        0.03
# LinearSVR                                    0.70       0.71  1.03        0.02
# PoissonRegressor                             0.70       0.70  1.04        0.02
# GammaRegressor                               0.54       0.54  1.28        0.03
# TweedieRegressor                             0.54       0.54  1.28        0.03
# ElasticNet                                   0.47       0.47  1.37        0.03
# RANSACRegressor                              0.47       0.47  1.38        0.05
# Lasso                                        0.37       0.37  1.50        0.01
# PassiveAggressiveRegressor                   0.14       0.15  1.75        0.02
# DummyRegressor                              -0.01      -0.01  1.90        0.00
# LassoLars                                   -0.01      -0.01  1.90        0.01
# KernelRidge                               -135.05    -134.57 22.06        0.20
